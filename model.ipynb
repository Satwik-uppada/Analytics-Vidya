# %%
# !pip install pandas openai elasticsearch

# %%
# import requests
# import pandas as pd 

# final_data = pd.read_csv("new_Data.csv")

# API_URL = "https://api-inference.huggingface.co/models/thenlper/gte-large"
# headers = {"Authorization": "Bearer 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"}

# def query(payload):
# 	response = requests.post(API_URL, headers=headers, json=payload)
# 	return response.json()
# combined_text_list = final_data['Combined Text'].tolist()	
# user_input = input("Enter your course keyword: ")
# output = query({
# 	"inputs": {
# 	"source_sentence": user_input,
# 	"sentences": combined_text_list
# },
# })

# output

# %%
# output

# %% [markdown]
# ----

# %%
from elasticsearch import Elasticsearch

es = Elasticsearch(
    "https://my-elasticsearch-project-d00981.es.us-east-1.aws.elastic.cloud:443",
    basic_auth=("search-tool","UjFnVXVwSUJSWFpTdXd5bEw4eE86VUFvVlhhc1VSaldCN28ybWdwMWFmQQ==")
)

es.ping()
# Out:
# False

# %% [markdown]
# """{
#   "name": "SATHVI-WORLD",
#   "cluster_name": "elasticsearch",
#   "cluster_uuid": "bRozVtclT1q8Lg41VGkK7g",
#   "version": {
#     "number": "8.15.3",
#     "build_flavor": "default",
#     "build_type": "zip",
#     "build_hash": "f97532e680b555c3a05e73a74c28afb666923018",
#     "build_date": "2024-10-09T22:08:00.328917561Z",
#     "build_snapshot": false,
#     "lucene_version": "9.11.1",
#     "minimum_wire_compatibility_version": "7.17.0",
#     "minimum_index_compatibility_version": "7.0.0"
#   },
#   "tagline": "You Know, for Search"
# }"""

# %% [markdown]
# ## Prepare the data

# %%
import pandas as pd
outside_data = pd.read_csv("analytics_vidhya_courses.csv")
outside_data
# Out:
#     Page Number                                              Title  \
# 0             1  GenAI Applied to Quantitative Finance: For Con...
# 1             1  Navigating LLM Tradeoffs: Techniques for Speed...
# 2             1  Creating Problem-Solving Agents using GenAI fo...
# 3             1  Improving Real World RAG Systems: Key Challeng...
# 4             1  Framework to Choose the Right LLM for your Bus...
# ..          ...                                                ...
# 63            8                              Tableau for Beginners
# 64            8               Getting Started with Neural Networks
# 65            8                            Introduction to AI & ML
# 66            8  Winning Data Science Hackathons - Learn from E...
# 67            8  Hypothesis Testing for Data Science and Analytics
#
#        Lessons Price                                          Image URL  \
# 0    5 Lessons  Free  https://import.cdn.thinkific.com/118220/0hkgoK...
# ...

# %%
outside_data.isna().sum()
# Out:
# Page Number     0
# Title           0
# Lessons         7
# Price           1
# Image URL       0
# Course Link     0
# Category       68
# dtype: int64

# %%
outside_data['Price'].unique()
# Out:
# array(['Free', nan, '₹999', '₹16999', '₹19999', '₹13999', '₹12999',
#        '₹14999', '₹3499', '₹14000'], dtype=object)

# %%
outside_data=outside_data[outside_data['Price'] == 'Free']
outside_data
# Out:
#     Page Number                                              Title  \
# 0             1  GenAI Applied to Quantitative Finance: For Con...
# 1             1  Navigating LLM Tradeoffs: Techniques for Speed...
# 2             1  Creating Problem-Solving Agents using GenAI fo...
# 3             1  Improving Real World RAG Systems: Key Challeng...
# 4             1  Framework to Choose the Right LLM for your Bus...
# 5             1  Building Smarter LLMs with Mamba and State Spa...
# 6             1        Generative AI - A Way of Life - Free Course
# 7             1  Building LLM Applications using Prompt Enginee...
# 8             1  Building Your First Computer Vision Model - Fr...
# 9             2   Bagging and Boosting ML Algorithms - Free Course
# 10            2  MidJourney: From Inspiration to Implementation...
# 11            2      Understanding Linear Regression - Free Course
# 12            2       The Working of Neural Networks - Free Course
# ...

# %%
outside_data.shape
# Out:
# (59, 7)

# %%
outside_data['Price'].unique()
# Out:
# array(['Free'], dtype=object)

# %%
import pandas as pd

inside_data = pd.read_csv("course_details.csv")
inside_data.head()
# Out:
#                                          Course Name  \
# 0  GenAI Applied to Quantitative Finance: For Con...
# 1  Navigating LLM Tradeoffs: Techniques for Speed...
# 2  Creating Problem-Solving Agents using GenAI fo...
# 3  Improving Real World RAG Systems: Key Challeng...
# 4  Framework to Choose the Right LLM for your Bus...
#
#                                          Description  \
# 0  This course explores the application of Genera...
# 1  This course provides a concise guide to optimi...
# 2  This introductory course provides a concise ov...
# 3  This course explores the key challenges in bui...
# 4  This course will guide you through the process...
#
#                                           Curriculum
# 0  {'1': {'title': 'Gen AI Applied to Quantitativ...
# 1  {'1': {'title': 'Navigating LLM Tradeoffs', 'l...
# 2  {'1': {'title': 'Creating Problem-Solving Agen...
# 3  {'1': {'title': 'Improving Real World RAG Syst...
# 4  {'1': {'title': 'Introduction', 'lessons': ['I...

# %%
inside_data.isna().sum()
# Out:
# Course Name    0
# Description    0
# Curriculum     0
# dtype: int64

# %%
inside_data.isna().value_counts()
# Out:
# Course Name  Description  Curriculum
# False        False        False         68
# Name: count, dtype: int64

# %% [markdown]
# ## Merging Files

# %%
outside_data.columns
# Out:
# Index(['Page Number', 'Title', 'Lessons', 'Price', 'Image URL', 'Course Link',
#        'Category'],
#       dtype='object')

# %%
outside_data.rename(columns={'Title':'Course Name'},inplace=True)
outside_data.drop(columns=['Category','Page Number'],inplace=True)
# Out:
# C:\Users\uppada satwik\AppData\Local\Temp\ipykernel_10316\2136776868.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outside_data.rename(columns={'Title':'Course Name'},inplace=True)
# C:\Users\uppada satwik\AppData\Local\Temp\ipykernel_10316\2136776868.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outside_data.drop(columns=['Category','Page Number'],inplace=True)

# %%
final_data = pd.merge(inside_data, outside_data,on='Course Name')
final_data
# Out:
#                                           Course Name  \
# 0   GenAI Applied to Quantitative Finance: For Con...
# 1   Navigating LLM Tradeoffs: Techniques for Speed...
# 2   Creating Problem-Solving Agents using GenAI fo...
# 3   Improving Real World RAG Systems: Key Challeng...
# 4   Framework to Choose the Right LLM for your Bus...
# 5   Building Smarter LLMs with Mamba and State Spa...
# 6         Generative AI - A Way of Life - Free Course
# 7   Building LLM Applications using Prompt Enginee...
# 8   Building Your First Computer Vision Model - Fr...
# 9    Bagging and Boosting ML Algorithms - Free Course
# 10  MidJourney: From Inspiration to Implementation...
# 11      Understanding Linear Regression - Free Course
# 12       The Working of Neural Networks - Free Course
# 13        The A to Z of Unsupervised ML - Free Course
# 14  Building Your first RAG System using LlamaInde...
# 15  Data Preprocessing on a Real-World Problem Sta...
# ...

# %%
# Function to flatten the curriculum (convert the dictionary structure to a readable string)
def flatten_curriculum(curriculum):
    try:
        # Convert the string representation of dictionary to an actual dictionary
        curriculum_dict = eval(curriculum)
        flattened_text = ""
        for chapter in curriculum_dict.values():
            flattened_text += f"Chapter: {chapter['title']}, Lessons: {', '.join(chapter['lessons'])}. "
        return flattened_text
    except Exception as e:
        return ""  # Return empty if there's an issue with the format

# Apply the flattening function to the 'Curriculum' column
final_data['Curriculum'] = final_data['Curriculum'].apply(flatten_curriculum)

# Combine Course Name, Description, and Flattened Curriculum
final_data['Combined Text'] = final_data['Course Name'] + " | " + final_data['Description'] + " |" + final_data['Curriculum']

# Display the updated DataFrame with the new column
final_data[['Course Name', 'Description', 'Curriculum', 'Combined Text']].head()
# Out:
#                                          Course Name  \
# 0  GenAI Applied to Quantitative Finance: For Con...
# 1  Navigating LLM Tradeoffs: Techniques for Speed...
# 2  Creating Problem-Solving Agents using GenAI fo...
# 3  Improving Real World RAG Systems: Key Challeng...
# 4  Framework to Choose the Right LLM for your Bus...
#
#                                          Description  \
# 0  This course explores the application of Genera...
# 1  This course provides a concise guide to optimi...
# 2  This introductory course provides a concise ov...
# 3  This course explores the key challenges in bui...
# 4  This course will guide you through the process...
#
#                                           Curriculum  \
# 0  Chapter: Gen AI Applied to Quantitative Financ...
# 1  Chapter: Navigating LLM Tradeoffs, Lessons: In...
# 2  Chapter: Creating Problem-Solving Agents using...
# 3  Chapter: Improving Real World RAG System, Less...
# ...

# %%
pickle_file_path = 'courses_data.pkl'
final_data.to_pickle(pickle_file_path)

# %% [markdown]
# ----

# %% [markdown]
# ## Convert the data to vectors using BERT model

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-mpnet-base-v2')

final_data["Embedding Vector"] = final_data["Combined Text"].apply(lambda x: model.encode(x))
# Out:
# c:\Users\uppada satwik\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
final_data["Embedding Vector"] = final_data["Combined Text"].apply(lambda x: model.encode(x))

# %%
final_data.head()
# Out:
#                                          Course Name  \
# 0  GenAI Applied to Quantitative Finance: For Con...
# 1  Navigating LLM Tradeoffs: Techniques for Speed...
# 2  Creating Problem-Solving Agents using GenAI fo...
# 3  Improving Real World RAG Systems: Key Challeng...
# 4  Framework to Choose the Right LLM for your Bus...
#
#                                          Description  \
# 0  This course explores the application of Genera...
# 1  This course provides a concise guide to optimi...
# 2  This introductory course provides a concise ov...
# 3  This course explores the key challenges in bui...
# 4  This course will guide you through the process...
#
#                                           Curriculum     Lessons Price  \
# 0  Chapter: Gen AI Applied to Quantitative Financ...   5 Lessons  Free
# 1  Chapter: Navigating LLM Tradeoffs, Lessons: In...   6 Lessons  Free
# 2  Chapter: Creating Problem-Solving Agents using...   6 Lessons  Free
# ...

# %%
final_data.to_csv("new_Data.csv",index=False)

# %%
final_data
# Out:
#                                           Course Name  \
# 0   GenAI Applied to Quantitative Finance: For Con...
# 1   Navigating LLM Tradeoffs: Techniques for Speed...
# 2   Creating Problem-Solving Agents using GenAI fo...
# 3   Improving Real World RAG Systems: Key Challeng...
# 4   Framework to Choose the Right LLM for your Bus...
# 5   Building Smarter LLMs with Mamba and State Spa...
# 6         Generative AI - A Way of Life - Free Course
# 7   Building LLM Applications using Prompt Enginee...
# 8   Building Your First Computer Vision Model - Fr...
# 9    Bagging and Boosting ML Algorithms - Free Course
# 10  MidJourney: From Inspiration to Implementation...
# 11      Understanding Linear Regression - Free Course
# 12       The Working of Neural Networks - Free Course
# 13        The A to Z of Unsupervised ML - Free Course
# 14  Building Your first RAG System using LlamaInde...
# 15  Data Preprocessing on a Real-World Problem Sta...
# ...

# %%
final_data.isna().sum()
# Out:
# Course Name         0
# Description         0
# Curriculum          0
# Lessons             1
# Price               0
# Image URL           0
# Course Link         0
# Combined Text       0
# Embedding Vector    0
# dtype: int64

# %%
vector_list = final_data['Embedding Vector'][0]

# %%
len(vector_list)
# Out:
# 768

# %%
final_data.fillna("",inplace=True)

# %%
from elasticsearch import Elasticsearch

client = Elasticsearch(
    "https://my-elasticsearch-project-d00981.es.us-east-1.aws.elastic.cloud:443",
    api_key="UjFnVXVwSUJSWFpTdXd5bEw4eE86VUFvVlhhc1VSaldCN28ybWdwMWFmQQ=="
)

index_name = "search-tool"

indexMapping = {
    "properties": {
        "Course Name": {
            "type": "text"
        },
        "Description": {
            "type": "text"
        },
        "Curriculum":{
            "type":'text'
        },
        "Lessons":{
           "type":'text'  
        },
        "Price":{
            "type":"text"
        },
        "Image URL":{
            "type":'text'
        },
        "Course URL":{
            "type":'keyword'
        },
        "Combined Text":{
            "type":"text"
        },
        "Embedding Vector": {
            "type": "dense_vector",
            "dims": 768, 
            "index":True,
            "similarity": "l2_norm"  
        }
    }
}


mapping_response = client.indices.put_mapping(index=index_name, body=indexMapping)
print(mapping_response)
# Out:
# {'acknowledged': True}

# %%
from elasticsearch import helpers
docs = final_data.to_dict("records")
bulk_response = helpers.bulk(client, docs, index=index_name)
print(bulk_response)
# Out:
# (58, [])

# %%
# Create the index
if not client.indices.exists(index=index_name):
    client.indices.create(index=index_name, body=indexMapping)
    print(f"Index '{index_name}' created successfully!")
else:
    print(f"Index '{index_name}' already exists.")
# Out:
# Index 'search-tool' already exists.

# %%
from elasticsearch import helpers

# Assume 'final_data' is your DataFrame with course data
docs = final_data.to_dict("records")
bulk_response = helpers.bulk(client, docs, index=index_name)

if bulk_response[0] == len(docs):
    print(f"{bulk_response[0]} documents indexed successfully.")
else:
    print("Some documents were not indexed.")
# Out:
# 58 documents indexed successfully.

# %%
client.ping()
# Out:
# True

# %%
search_query = {
    "query": {
        "multi_match": {
            "query": "machine learning",  # Replace with your actual search term
            "fields": ["Course Name", "Description",'Course Link','Curriculum']
        },
    },
     "_source": ["Course Name", "Description", "Course Link", 'Curriculum']
}

response = client.search(index=index_name, body=search_query)
print("Search results:", response['hits']['hits'])
# Out:
# Search results: [{'_index': 'search-tool', '_id': 'ElhPupIBRXZSuwylwc3u', '_score': 4.9273634, '_source': {'Course Name': 'Machine Learning Summer Training', 'Description': 'This is the second step of the Machine Learning Summer Training, want to know more click here.', 'Curriculum': 'Chapter: Overview of the Course, Lessons: AI&ML Blackbelt Plus Program (Sponsored). Chapter: Introduction to Data Science and Machine Learning, Lessons: Overview of Machine Learning / Data Science, Common Terminology used in Data Science, Applications of Data Science. Chapter: Setting up your system, Lessons: Installation steps for Windows, Installation steps for Linux, Installation steps for Mac. Chapter: Introduction to Python, Lessons: Introduction to Python, Introduction to Jupyter Notebook, Download Python Module Handouts. Chapter: Variables and Data Types, Lessons: Introduction to Variables, Implementing Variables in Python. Chapter: Operators, Lessons: Introduction to Operators, Implementing Oper
# ...

# %%
response['hits']['hits']
# Out:
# [{'_index': 'search-tool',
#   '_id': 'ElhPupIBRXZSuwylwc3u',
#   '_score': 4.9273634,
#   '_source': {'Course Name': 'Machine Learning Summer Training',
#    'Description': 'This is the second step of the Machine Learning Summer Training, want to know more click here.',
# ...

# %% [markdown]
# ----

# %%
input_keyword = "Generative AI of 5 lessons begineer friendly course"
vector_of_input_keyword = get_embeddings(input_keyword,tokenizer,model)

# %%
topics_list = ["Business Analytics", "Deep Learning", "Generative AI", "Machine Learning", "Natural Language Processing (NLP)", "Projects", "Tools"]
levels =  ["Beginner", "Intermediate", "Advanced"]

my_prompt = f"""I have data in an Elasticsearch index containing all courses with their descriptions, course name, no.of lessons, Curriculum .
Topics available are {topics_list}.
Difficulty levels are {levels}.
Lessons can range from 5 lessons to 50 Lessons.

Based on the user's search query, give me a JSON output in the following format:
{{
"topic": "It should be one of the available topics from the list above. If the topic is not mentioned in the query, return Not-Mentioned. If the topic mentioned by the user is not present in the list, return Not-Found.",
"difficulty": "The difficulty level should be one of the list above. If not specified by the user, return Not-Mentioned.",
"max_duration": "The maximum lessons for the course based on the query. If not mentioned, return Not-Mentioned.",
"min_duration": "The minimum lessons for the course based on the query. If not mentioned, return Not-Mentioned."
}}

You are a helpful assistant designed to output only in JSON format. No other text or explaination.

User's query: {input_keyword}
"""
